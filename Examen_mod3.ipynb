# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %% [markdown]
# # FASE 1 (PARTE I)

# %% [markdown]
# - ARCHIVO CUSTOMER LOYALTY HISTORY

# %%
# Lectura del archivo Loyalty 
df_loyalty = pd.read_csv("Customer Loyalty History.csv") 
df_loyalty.head()

#unir año y mes
# Out:
#    Loyalty Number Country          Province       City Postal Code  Gender  \
# 0          480934  Canada           Ontario    Toronto     M2Z 4K1  Female
# 1          549612  Canada           Alberta   Edmonton     T3G 6Y6    Male
# 2          429460  Canada  British Columbia  Vancouver     V6E 3D9    Male
# 3          608370  Canada           Ontario    Toronto     P1W 1K4    Male
# 4          530508  Canada            Quebec       Hull     J8Y 3Z5    Male
#
#   Education    Salary Marital Status Loyalty Card      CLV Enrollment Type  \
# 0  Bachelor   83236.0        Married         Star  3839.14        Standard
# 1   College       NaN       Divorced         Star  3839.61        Standard
# 2   College       NaN         Single         Star  3839.75        Standard
# 3   College       NaN         Single         Star  3839.75        Standard
# 4  Bachelor  103495.0        Married         Star  3842.79        Standard
#
#    Enrollment Year  Enrollment Month  Cancellation Year  Cancellation Month
# 0             2016                 2                NaN                 NaN
# 1             2016                 3                NaN                 NaN
# 2             2014                 7             2018.0                 1.0
# 3             2013                 2                NaN                 NaN
# 4             2014                10                NaN                 NaN

# %%
#Verificación de dimensiones
df_loyalty.shape
# Out:
# (16737, 16)

# %%
# verificar detalle de las columnas (años y meses cambiar formato)
df_loyalty.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 16737 entries, 0 to 16736
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Loyalty Number      16737 non-null  int64
#  1   Country             16737 non-null  str
#  2   Province            16737 non-null  str
#  3   City                16737 non-null  str
#  4   Postal Code         16737 non-null  str
#  5   Gender              16737 non-null  str
#  6   Education           16737 non-null  str
#  7   Salary              12499 non-null  float64
#  8   Marital Status      16737 non-null  str
#  9   Loyalty Card        16737 non-null  str
#  10  CLV                 16737 non-null  float64
#  11  Enrollment Type     16737 non-null  str
#  12  Enrollment Year     16737 non-null  int64
#  13  Enrollment Month    16737 non-null  int64
#  14  Cancellation Year   2067 non-null   float64
#  15  Cancellation Month  2067 non-null   float64
# dtypes: float64(4), int64(3), str(9)
# memory usage: 2.0 MB

# %%
# Detectar columnas con nulos (3) 
round(df_loyalty.isna().sum()/df_loyalty.shape[0]*100),2 #redondeo a 2 decimales
# Out:
# (Loyalty Number         0.0
#  Country                0.0
#  Province               0.0
#  City                   0.0
#  Postal Code            0.0
#  Gender                 0.0
#  Education              0.0
#  Salary                25.0
#  Marital Status         0.0
#  Loyalty Card           0.0
#  CLV                    0.0
#  Enrollment Type        0.0
#  Enrollment Year        0.0
#  Enrollment Month       0.0
#  Cancellation Year     88.0
#  Cancellation Month    88.0
#  dtype: float64,
#  2)

# %%
#verifico duplicados
df_loyalty.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Datos estadisticos (columna Salario -)
df_loyalty.describe(include=np.number).T
# Out:
#                       count           mean            std        min  \
# Loyalty Number      16737.0  549735.880445  258912.132453  100018.00
# Salary              12499.0   79245.609409   35008.297285  -58486.00
# CLV                 16737.0    7988.896536    6860.982280    1898.01
# Enrollment Year     16737.0    2015.253211       1.979111    2012.00
# Enrollment Month    16737.0       6.669116       3.398958       1.00
# Cancellation Year    2067.0    2016.503145       1.380743    2013.00
# Cancellation Month   2067.0       6.962748       3.455297       1.00
#
#                           25%        50%        75%        max
# Loyalty Number      326603.00  550434.00  772019.00  999986.00
# Salary               59246.50   73455.00   88517.50  407228.00
# CLV                   3980.84    5780.18    8940.58   83325.38
# Enrollment Year       2014.00    2015.00    2017.00    2018.00
# Enrollment Month         4.00       7.00      10.00      12.00
# Cancellation Year     2016.00    2017.00    2018.00    2018.00
# Cancellation Month       4.00       7.00      10.00      12.00

# %%
#clientes con salarios en negativo y busco relación ( promotion: 2018, año de suscripción: 2018, Meses 2-3-4)
df_loyalty[df_loyalty["Salary"] < 0]
# Out:
#        Loyalty Number Country          Province            City Postal Code  \
# 1082           542976  Canada            Quebec        Montreal     H2Y 4R4
# 1894           959977  Canada  British Columbia       Vancouver     V5R 1W3
# 2471           232755  Canada  British Columbia       Vancouver     V1E 4R6
# 3575           525245  Canada  British Columbia        Victoria     V10 6T5
# 3932           603070  Canada  British Columbia  West Vancouver     V6V 8Z3
# 4712           491242  Canada  British Columbia    Dawson Creek     U5I 4F1
# 6560           115505  Canada      Newfoundland      St. John's     A1C 6H9
# 6570           430398  Canada      Newfoundland      St. John's     A1C 6H9
# 7373           152016  Canada           Ontario         Toronto     P1J 8T7
# 8576           194065  Canada           Ontario         Sudbury     M5V 1G5
# 8767           212128  Canada           Ontario         Toronto     P2T 6G3
# 10232          790475  Canada           Ontario         Trenton     K8V 4B2
# 11635          366599  Canada           Ontario         Toronto     M1R 4K3
# 12596          436087  Canada            Quebec        Montreal     H2T 9K8
# 13564          364596  Canada            Quebec       Tremblant     H5Y 2S9
# 14327          239955  Canada            Quebec            Hull     J8Y 3Z5
# 14355          347013  Canada            Quebec     Quebec City     G1B 3L5
# 15416          729561  Canada            Quebec     Quebec City     G1B 3L5
# 16431          734647  Canada      Saskatchewan          Regina     S1J 3C5
# 16735          906428  Canada             Yukon      Whitehorse     Y2K 6R0
#
#        Gender             Education   Salary Marital Status Loyalty Card  \
# 1082     Male  High School or Below -49830.0       Divorced         Star
# 1894   Female              Bachelor -12497.0        Married       Aurora
# 2471   Female              Bachelor -46683.0         Single         Nova
# 3575     Male              Bachelor -45962.0        Married         Star
# 3932   Female              Bachelor -19325.0         Single         Star
# 4712     Male              Bachelor -43234.0        Married         Star
# 6560     Male              Bachelor -10605.0        Married         Nova
# 6570     Male              Bachelor -17534.0        Married         Nova
# 7373   Female              Bachelor -58486.0        Married       Aurora
# 8576   Female              Bachelor -31911.0        Married         Nova
# 8767     Male              Bachelor -49001.0        Married         Nova
# 10232  Female              Bachelor -34079.0        Married         Nova
# 11635  Female              Bachelor  -9081.0        Married         Star
# 12596    Male              Bachelor -46470.0        Married         Star
# 13564  Female              Bachelor -26322.0         Single       Aurora
# 14327  Female              Bachelor -47310.0        Married         Nova
# 14355    Male              Bachelor -39503.0        Married         Nova
# 15416  Female              Bachelor -19332.0       Divorced         Star
# 16431    Male              Bachelor -46303.0        Married         Nova
# 16735    Male              Bachelor -57297.0        Married         Star
#
#             CLV Enrollment Type  Enrollment Year  Enrollment Month  \
# 1082   24127.50  2018 Promotion             2018                 3
# 1894    9453.00  2018 Promotion             2018                 3
# 2471    4787.81  2018 Promotion             2018                 3
# 3575    2402.33  2018 Promotion             2018                 3
# 3932    2893.74  2018 Promotion             2018                 3
# 4712    7597.91  2018 Promotion             2018                 3
# 6560    5860.17  2018 Promotion             2018                 4
# 6570   49423.80  2018 Promotion             2018                 3
# 7373    5067.21  2018 Promotion             2018                 2
# 8576    2888.85  2018 Promotion             2018                 2
# 8767    3130.68  2018 Promotion             2018                 2
# 10232  12913.50  2018 Promotion             2018                 2
# 11635   6915.73  2018 Promotion             2018                 4
# 12596   4786.89  2018 Promotion             2018                 4
# 13564  16710.84  2018 Promotion             2018                 4
# 14327   6366.23  2018 Promotion             2018                 3
# 14355   6446.71  2018 Promotion             2018                 3
# 15416   5308.29  2018 Promotion             2018                 2
# 16431  11280.73  2018 Promotion             2018                 4
# 16735  10018.66  2018 Promotion             2018                 4
#
#        Cancellation Year  Cancellation Month
# 1082                 NaN                 NaN
# 1894                 NaN                 NaN
# 2471                 NaN                 NaN
# 3575                 NaN                 NaN
# 3932                 NaN                 NaN
# 4712                 NaN                 NaN
# 6560                 NaN                 NaN
# 6570                 NaN                 NaN
# 7373                 NaN                 NaN
# 8576                 NaN                 NaN
# 8767                 NaN                 NaN
# 10232                NaN                 NaN
# 11635                NaN                 NaN
# 12596             2018.0                 8.0
# 13564             2018.0                12.0
# 14327                NaN                 NaN
# 14355                NaN                 NaN
# 15416                NaN                 NaN
# 16431                NaN                 NaN
# 16735                NaN                 NaN

# %%
#tambien tengo nulos en esa columna
df_loyalty["Salary"].isna().sum()
# Out:
# np.int64(4238)

# %%
clientes_salario_negativo=df_loyalty[df_loyalty["Salary"] < 0]
#confirmo la cantidad
print(clientes_salario_negativo.shape)
# Out:
# (20, 16)

# %%
# Todos los registros son del pais Canadá
df_loyalty.describe(include="str").T
# Out:
#                  count unique       top   freq
# Country          16737      1    Canada  16737
# Province         16737     11   Ontario   5404
# City             16737     29   Toronto   3351
# Postal Code      16737     55   V6E 3D9    911
# Gender           16737      2    Female   8410
# Education        16737      5  Bachelor  10475
# Marital Status   16737      3   Married   9735
# Loyalty Card     16737      3      Star   7637
# Enrollment Type  16737      2  Standard  15766

# %%
#Analizo si hay datos duplicados (error de escritura)
columnas_revisar = ["Country", "Province", "Gender", "Education", "Marital Status", "Loyalty Card", "Enrollment Type"]

for col in columnas_revisar:
    print(f"Columna: {col}")
    print(df_loyalty[col].unique())
    print("-" * 50)
# Out:
# Columna: Country
# <StringArray>
# ['Canada']
# Length: 1, dtype: str
# --------------------------------------------------
# Columna: Province
# <StringArray>
# [             'Ontario',              'Alberta',     'British Columbia',
#                'Quebec',                'Yukon',        'New Brunswick',
#              'Manitoba',          'Nova Scotia',         'Saskatchewan',
#          'Newfoundland', 'Prince Edward Island']
# Length: 11, dtype: str
# --------------------------------------------------
# Columna: Gender
# <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str
# --------------------------------------------------
# Columna: Education
# <StringArray>
# ['Bachelor', 'College', 'Master', 'High School or Below', 'Doctor']
# Length: 5, dtype: str
# --------------------------------------------------
# Columna: Marital Status
# <StringArray>
# ['Married', 'Divorced', 'Single']
# Length: 3, dtype: str
# --------------------------------------------------
# Columna: Loyalty Card
# <StringArray>
# ['Star', 'Aurora', 'Nova']
# Length: 3, dtype: str
# --------------------------------------------------
# Columna: Enrollment Type
# <StringArray>
# ['Standard', '2018 Promotion']
# Length: 2, dtype: str
# --------------------------------------------------

# %%
#Analizo los datos en columnas numericas (error de escritura) todos ok, hay numos pero son losdel 88%
columnas_num = ["Enrollment Year", "Enrollment Month", "Cancellation Year", "Cancellation Month"]

for col in columnas_num:
    print(f"Columna: {col}")
    print(df_loyalty[col].unique())
    print("-" * 50)
# Out:
# Columna: Enrollment Year
# [2016 2014 2013 2012 2015 2018 2017]
# --------------------------------------------------
# Columna: Enrollment Month
# [ 2  3  7 10  5  6 12  1 11  8  4  9]
# --------------------------------------------------
# Columna: Cancellation Year
# [  nan 2018. 2015. 2017. 2014. 2016. 2013.]
# --------------------------------------------------
# Columna: Cancellation Month
# [nan  1. 12.  4.  2.  7. 11.  5.  6. 10.  8.  9.  3.]
# --------------------------------------------------

# %% [markdown]
# - Archivo FLIGHT ACTIVITY

# %%
# Lectura del csv flight Activity
df_flight=pd.read_csv("Customer Flight Activity.csv")
df_flight.head()
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    Dollar Cost Points Redeemed
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0

# %%
#verifico dimensiones del dataset
df_flight.shape
# Out:
# (405624, 10)

# %%
#reviso tipo y formato
df_flight.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 405624 entries, 0 to 405623
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Loyalty Number               405624 non-null  int64
#  1   Year                         405624 non-null  int64
#  2   Month                        405624 non-null  int64
#  3   Flights Booked               405624 non-null  int64
#  4   Flights with Companions      405624 non-null  int64
#  5   Total Flights                405624 non-null  int64
#  6   Distance                     405624 non-null  int64
#  7   Points Accumulated           405624 non-null  float64
#  8   Points Redeemed              405624 non-null  int64
#  9   Dollar Cost Points Redeemed  405624 non-null  int64
# dtypes: float64(1), int64(9)
# memory usage: 30.9 MB

# %%
#verifico duplicados 
df_flight.duplicated().sum()
# Out:
# np.int64(1864)

# %%
#Aislo los duplicados y sus copias
vuelos_duplicados = df_flight[df_flight.duplicated(keep=False)]
vuelos_duplicados
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 41              101902  2017      1               0                        0
# 42              101902  2017      1               0                        0
# 226             112142  2017      1               0                        0
# 227             112142  2017      1               0                        0
# 477             126100  2017      1               0                        0
# ...                ...   ...    ...             ...                      ...
# 405111          971370  2018     12               0                        0
# 405409          988392  2018     12               0                        0
# 405410          988392  2018     12               0                        0
# 405436          989528  2018     12               0                        0
# 405437          989528  2018     12               0                        0
#
#         Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 41                  0         0                 0.0                0
# 42                  0         0                 0.0                0
# 226                 0         0                 0.0                0
# 227                 0         0                 0.0                0
# 477                 0         0                 0.0                0
# ...               ...       ...                 ...              ...
# 405111              0         0                 0.0                0
# 405409              0         0                 0.0                0
# 405410              0         0                 0.0                0
# 405436              0         0                 0.0                0
# 405437              0         0                 0.0                0
#
#         Dollar Cost Points Redeemed
# 41                                0
# 42                                0
# 226                               0
# 227                               0
# 477                               0
# ...                             ...
# 405111                            0
# 405409                            0
# 405410                            0
# 405436                            0
# 405437                            0
#
# [3712 rows x 10 columns]

# %%
#Elimino duplicados 
df_flight.drop_duplicates(inplace = True)

# %%
#compruebo que ya no hay
df_flight.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Detectar nulos (0 columnas con nulos)
round(df_flight.isna().sum()/df_flight.shape[0]*100),2
# Out:
# (Loyalty Number                 0.0
#  Year                           0.0
#  Month                          0.0
#  Flights Booked                 0.0
#  Flights with Companions        0.0
#  Total Flights                  0.0
#  Distance                       0.0
#  Points Accumulated             0.0
#  Points Redeemed                0.0
#  Dollar Cost Points Redeemed    0.0
#  dtype: float64,
#  2)

# %%
#Estadisticas del dataset
df_flight.describe(include=np.number).T #2017 al 2018 / maximo e viajes en un cliente 32
# Out:
#                                 count           mean            std       min  \
# Loyalty Number               403760.0  549875.383713  258961.514684  100018.0
# Year                         403760.0    2017.500352       0.500000    2017.0
# Month                        403760.0       6.501335       3.451982       1.0
# Flights Booked               403760.0       4.134050       5.230064       0.0
# Flights with Companions      403760.0       1.036569       2.080472       0.0
# Total Flights                403760.0       5.170619       6.526858       0.0
# Distance                     403760.0    1214.460979    1434.098521       0.0
# Points Accumulated           403760.0     124.263761     146.696179       0.0
# Points Redeemed              403760.0      30.838587     125.758002       0.0
# Dollar Cost Points Redeemed  403760.0       2.495973      10.172033       0.0
#
#                                   25%       50%       75%       max
# Loyalty Number               326699.0  550598.0  772152.0  999986.0
# Year                           2017.0    2018.0    2018.0    2018.0
# Month                             4.0       7.0      10.0      12.0
# Flights Booked                    0.0       1.0       8.0      21.0
# Flights with Companions           0.0       0.0       1.0      11.0
# Total Flights                     0.0       1.0      10.0      32.0
# Distance                          0.0     525.0    2342.0    6293.0
# Points Accumulated                0.0      53.0     240.0     676.5
# Points Redeemed                   0.0       0.0       0.0     876.0
# Dollar Cost Points Redeemed       0.0       0.0       0.0      71.0

# %%
#quienes son los viajeros mas frecuentes (27) / mes alta demanda julio
viajeros_frecuentes = df_flight[df_flight["Total Flights"] == 32]
viajeros_frecuentes
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 102525          160773  2017      7              21                       11
# 107260          413741  2017      7              21                       11
# 109113          510513  2017      7              21                       11
# 110368          577156  2017      7              21                       11
# 111951          661502  2017      7              21                       11
# 196563          708807  2018      7              21                       11
# 305777          184151  2018      7              21                       11
# 306166          204000  2018      7              21                       11
# 308138          310700  2018      7              21                       11
# 308475          328303  2018      7              21                       11
# 309616          389551  2018      7              21                       11
# 309880          403893  2018      7              21                       11
# 310020          411523  2018      7              21                       11
# 311848          506170  2018      7              21                       11
# 312167          523642  2018      7              21                       11
# 312592          546997  2018      7              21                       11
# 314716          659205  2018      7              21                       11
# 315068          677527  2018      7              21                       11
# 315511          700918  2018      7              21                       11
# 316065          729561  2018      7              21                       11
# 317920          828895  2018      7              21                       11
# 317996          832864  2018      7              21                       11
# 318331          849425  2018      7              21                       11
# 320623          972298  2018      7              21                       11
# 320974          459164  2018      7              21                       11
# 380028          713085  2018      7              21                       11
# 396749          286551  2018      7              21                       11
#
#         Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 102525             32      5888               588.0                0
# 107260             32      2368               236.0                0
# 109113             32      5984               598.0                0
# 110368             32      5536               553.0                0
# 111951             32      2848               284.0                0
# 196563             32      4896               489.0              748
# 305777             32      3776               377.0                0
# 306166             32      2720               272.0                0
# 308138             32      4960               496.0                0
# 308475             32      5152               515.0                0
# 309616             32      2368               236.0                0
# 309880             32      4928               492.0                0
# 310020             32      5344               534.0                0
# 311848             32      4768               476.0                0
# 312167             32      5888               588.0                0
# 312592             32      4192               419.0                0
# 314716             32      2720               272.0                0
# 315068             32      2496               249.0                0
# 315511             32      3648               364.0                0
# 316065             32      5536               553.0                0
# 317920             32      3808               380.0                0
# 317996             32      3616               361.0                0
# 318331             32      2752               275.0                0
# 320623             32      3040               304.0                0
# 320974             32      2784               278.0              513
# 380028             32      2208               220.0              492
# 396749             32      2144               214.0              831
#
#         Dollar Cost Points Redeemed
# 102525                            0
# 107260                            0
# 109113                            0
# 110368                            0
# 111951                            0
# 196563                           60
# 305777                            0
# 306166                            0
# 308138                            0
# 308475                            0
# 309616                            0
# 309880                            0
# 310020                            0
# 311848                            0
# 312167                            0
# 312592                            0
# 314716                            0
# 315068                            0
# 315511                            0
# 316065                            0
# 317920                            0
# 317996                            0
# 318331                            0
# 320623                            0
# 320974                           42
# 380028                           40
# 396749                           67

# %% [markdown]
# # FASE 1 (PARTE II)

# %% [markdown]
# - Transformación de datos

# %% [markdown]
# - Nulos Columna Salario

# %%
#Se transformaron los salarios negativos a positivos porque la cifra es coherente con el mercado, se determina que el signo es un error . 
df_loyalty["Salary"] = df_loyalty["Salary"].abs() #abs (valor absoluto +)

# %%
#Los nulos estan en la clasificación collage
conteo_nulos = df_loyalty[df_loyalty["Salary"].isna()].groupby("Education").size()
conteo_nulos
# Out:
# Education
# College    4238
# dtype: int64

# %%
#no puedo amputar por a mediana de collage porque es nan completa
df_loyalty.groupby("Education")["Salary"].median()
# Out:
# Education
# Bachelor                 71960.0
# College                      NaN
# Doctor                  182143.5
# High School or Below     61915.0
# Master                  105487.0
# Name: Salary, dtype: float64

# %%
#compruebo hacia donde se inclinan los salarios
plt.figure(figsize=(8, 5))
sns.boxplot(x=df_loyalty["Salary"], color="skyblue")
plt.title("Distribución de Salarios y Outliers")
plt.show()

# %%
#he decidido amputar por la mediana global
df_loyalty["Salary"] = df_loyalty["Salary"].fillna(df_loyalty["Salary"].median())

# %%
df_loyalty["Salary"].isna().sum()
# Out:
# np.int64(0)

# %%
#Unificamos los archivos
df_unificado = pd.merge(df_flight, df_loyalty, on="Loyalty Number", how="left")

# %%
#verifico nuevas dimensiones
df_unificado.shape
# Out:
# (403760, 25)

# %%
#compruebo el cambio
df_unificado.describe(include=np.number).T
# Out:
#                                 count           mean            std  \
# Loyalty Number               403760.0  549875.383713  258961.514684
# Year                         403760.0    2017.500352       0.500000
# Month                        403760.0       6.501335       3.451982
# Flights Booked               403760.0       4.134050       5.230064
# Flights with Companions      403760.0       1.036569       2.080472
# Total Flights                403760.0       5.170619       6.526858
# Distance                     403760.0    1214.460979    1434.098521
# Points Accumulated           403760.0     124.263761     146.696179
# Points Redeemed              403760.0      30.838587     125.758002
# Dollar Cost Points Redeemed  403760.0       2.495973      10.172033
# Salary                       403760.0   77873.206286   30118.457422
# CLV                          403760.0    7990.864857    6863.317160
# Enrollment Year              403760.0    2015.250716       1.979427
# Enrollment Month             403760.0       6.667555       3.398829
# Cancellation Year             49650.0    2016.504350       1.380482
# Cancellation Month            49650.0       6.962095       3.454362
#
#                                    min        25%        50%        75%  \
# Loyalty Number               100018.00  326699.00  550598.00  772152.00
# Year                           2017.00    2017.00    2018.00    2018.00
# Month                             1.00       4.00       7.00      10.00
# Flights Booked                    0.00       0.00       1.00       8.00
# Flights with Companions           0.00       0.00       0.00       1.00
# Total Flights                     0.00       0.00       1.00      10.00
# Distance                          0.00       0.00     525.00    2342.00
# Points Accumulated                0.00       0.00      53.00     240.00
# Points Redeemed                   0.00       0.00       0.00       0.00
# Dollar Cost Points Redeemed       0.00       0.00       0.00       0.00
# Salary                         9081.00   63901.00   73455.00   82940.00
# CLV                            1898.01    3981.78    5776.34    8937.12
# Enrollment Year                2012.00    2014.00    2015.00    2017.00
# Enrollment Month                  1.00       4.00       7.00      10.00
# Cancellation Year              2013.00    2016.00    2017.00    2018.00
# Cancellation Month                1.00       4.00       7.00      10.00
#
#                                    max
# Loyalty Number               999986.00
# Year                           2018.00
# Month                            12.00
# Flights Booked                   21.00
# Flights with Companions          11.00
# Total Flights                    32.00
# Distance                       6293.00
# Points Accumulated              676.50
# Points Redeemed                 876.00
# Dollar Cost Points Redeemed      71.00
# Salary                       407228.00
# CLV                           83325.38
# Enrollment Year                2018.00
# Enrollment Month                 12.00
# Cancellation Year              2018.00
# Cancellation Month               12.00

# %% [markdown]
#  - Columnas Cancellation Year y Cancellation Month: He decidido mantener los nulos en las fechas de calcelación . Es lógico que existan, indican que el cliente no ha cancelado su cuenta y cambiarlos como errores sería incorrecto

# %%
# Creo una nueva columna (Status) donde me indique si la membresia esta activa o inactiva, es mas funcional.
df_unificado["Status"] = np.where(df_unificado["Cancellation Year"].isnull(), "Activo", "Inactivo") #np.where Si el valor de la columna es nulo transformalo a activo sino está inactivo 
df_unificado.head(2)
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
#
#    Dollar Cost Points Redeemed Country Province      City Postal Code  Gender  \
# 0                            0  Canada  Alberta  Edmonton     T9G 1W3  Female
# 1                            0  Canada  Ontario   Toronto     M1R 4K3    Male
#
#   Education   Salary Marital Status Loyalty Card      CLV Enrollment Type  \
# 0  Bachelor  92552.0        Married       Aurora  7919.20        Standard
# 1   College  73455.0         Single         Nova  2887.74        Standard
#
#    Enrollment Year  Enrollment Month  Cancellation Year  Cancellation Month  \
# 0             2016                 8                NaN                 NaN
# 1             2013                 3                NaN                 NaN
#
#    Status
# 0  Activo
# 1  Activo

# %%
#verifico cantidades en columna Status
df_unificado["Status"].value_counts()
# Out:
# Status
# Activo      354110
# Inactivo     49650
# Name: count, dtype: int64

# %% [markdown]
# # FASE 2
# - Análisis Estadístico

# %%
# Estadistica descriptiva Variables numericas
df_unificado.describe(include=np.number).T
# Out:
#                                 count           mean            std  \
# Loyalty Number               403760.0  549875.383713  258961.514684
# Year                         403760.0    2017.500352       0.500000
# Month                        403760.0       6.501335       3.451982
# Flights Booked               403760.0       4.134050       5.230064
# Flights with Companions      403760.0       1.036569       2.080472
# Total Flights                403760.0       5.170619       6.526858
# Distance                     403760.0    1214.460979    1434.098521
# Points Accumulated           403760.0     124.263761     146.696179
# Points Redeemed              403760.0      30.838587     125.758002
# Dollar Cost Points Redeemed  403760.0       2.495973      10.172033
# Salary                       403760.0   77873.206286   30118.457422
# CLV                          403760.0    7990.864857    6863.317160
# Enrollment Year              403760.0    2015.250716       1.979427
# Enrollment Month             403760.0       6.667555       3.398829
# Cancellation Year             49650.0    2016.504350       1.380482
# Cancellation Month            49650.0       6.962095       3.454362
#
#                                    min        25%        50%        75%  \
# Loyalty Number               100018.00  326699.00  550598.00  772152.00
# Year                           2017.00    2017.00    2018.00    2018.00
# Month                             1.00       4.00       7.00      10.00
# Flights Booked                    0.00       0.00       1.00       8.00
# Flights with Companions           0.00       0.00       0.00       1.00
# Total Flights                     0.00       0.00       1.00      10.00
# Distance                          0.00       0.00     525.00    2342.00
# Points Accumulated                0.00       0.00      53.00     240.00
# Points Redeemed                   0.00       0.00       0.00       0.00
# Dollar Cost Points Redeemed       0.00       0.00       0.00       0.00
# Salary                         9081.00   63901.00   73455.00   82940.00
# CLV                            1898.01    3981.78    5776.34    8937.12
# Enrollment Year                2012.00    2014.00    2015.00    2017.00
# Enrollment Month                  1.00       4.00       7.00      10.00
# Cancellation Year              2013.00    2016.00    2017.00    2018.00
# Cancellation Month                1.00       4.00       7.00      10.00
#
#                                    max
# Loyalty Number               999986.00
# Year                           2018.00
# Month                            12.00
# Flights Booked                   21.00
# Flights with Companions          11.00
# Total Flights                    32.00
# Distance                       6293.00
# Points Accumulated              676.50
# Points Redeemed                 876.00
# Dollar Cost Points Redeemed      71.00
# Salary                       407228.00
# CLV                           83325.38
# Enrollment Year                2018.00
# Enrollment Month                 12.00
# Cancellation Year              2018.00
# Cancellation Month               12.00

# %%
#Parece que no depende del sueldo la cantidad de viajes 

bins = [0, 5, 15, 32]
labels = ['0-5 (Bajo)', '6-15 (Medio)', '16-32 (Alto)']
df_unificado['Flight_Range'] = pd.cut(df_unificado['Total Flights'], bins=bins, labels=labels)


plt.figure(figsize=(10, 6))
sns.boxplot(x='Flight_Range', y='Salary', data=df_unificado, palette='viridis')

plt.title('¿Ganan más los que más vuelan?', fontsize=16, fontweight='bold')
plt.xlabel('Rango de Vuelos Totales', fontsize=13)
plt.ylabel('Salario Anual', fontsize=13)
plt.show()

# %%
#Casi Nadie viaja acompañado
sns.histplot(df_unificado["Flights with Companions"], color='skyblue', discrete=True)

plt.title('¿Cuánta gente viaja sola vs. acompañada?')
plt.xlabel('Número de Acompañantes')
plt.ylabel('Cantidad de Vuelos')
plt.xticks(range(0, 12))
plt.show()

# %%
#la mayoria no está canjeando los puntos, quizas la cantidad de puntos para desbloquear un premio debe ser alto para poder gastarlo.
sns.histplot(df_unificado["Points Accumulated"], kde=True, color='gold', bins=50)
plt.axvline(df_unificado["Points Accumulated"].mean(), color='red', linestyle='--', label='Media')
plt.axvline(df_unificado["Points Accumulated"].median(), color='green', linestyle='-', label='Mediana')

plt.title('Distribución de Puntos Acumulados: ¿Cuánto ahorran nuestros clientes?')
plt.xlabel('Puntos Acumulados')
plt.ylabel('Cantidad de Registros')
plt.legend()
plt.show()

# %% [markdown]
# -Análisis de variables categóricas:
#
# - Distribución de frecuencias de las variables categóricas relevantes.

# %%
# Estadistica descriptiva Variables numericas
df_unificado.describe(include="str").T
# Out:
#                   count unique       top    freq
# Country          403760      1    Canada  403760
# Province         403760     11   Ontario  130258
# City             403760     29   Toronto   80775
# Postal Code      403760     55   V6E 3D9   21944
# Gender           403760      2    Female  202757
# Education        403760      5  Bachelor  252567
# Marital Status   403760      3   Married  234845
# Loyalty Card     403760      3      Star  183745
# Enrollment Type  403760      2  Standard  380419
# Status           403760      2    Activo  354110

# %%
#Las provincias que mas viajan son Ontario, British Columbia y Quebec
sns.set_theme(style="whitegrid")
plt.figure(figsize=(12, 6))

orden = df_unificado['Province'].value_counts().index
sns.countplot(data=df_unificado, y='Province', order=orden, palette='viridis')
plt.title('Distribución de Clientes por Provincia', fontsize=15, fontweight='bold')
plt.xlabel('Número de Clientes')
plt.ylabel('Provincia')
plt.show()

# %%
#clasificación de clientes por segmento de categoria 

data = df_unificado['Loyalty Card'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(data, labels=data.index, autopct='%1.1f%%', startangle=140, 
        colors=['#4e79a7', '#f28e2b', '#e15759'], wedgeprops={'edgecolor': 'white'})

centre_circle = plt.Circle((0,0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title('Cuota de Mercado por Tipo de Tarjeta', fontsize=15, fontweight='bold')
plt.show()

# %%
#Casados viajan mas luego solteros y finalmente divorciados

plt.figure(figsize=(12, 6))

sns.countplot(data=df_unificado, x='Marital Status', hue='Gender', palette='Set2')
plt.title('Perfil Demográfico: Estado Civil vs Género', fontsize=15, fontweight='bold')
plt.xlabel('Estado Civil')
plt.ylabel('Cantidad de Clientes')
plt.legend(title='Género')
plt.show()

# %% [markdown]
# # FASE 3
#
# - Usando las herramientas de visualización que has aprendido durante este módulo, contesta a las siguientes
# preguntas usando la mejor gráfica que consideres:
